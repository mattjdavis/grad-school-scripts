# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Plot" data-toc-modified-id="Plot-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Plot</a></span></li></ul></div>

# %%
df_hr = pd.read_csv('PC-DATA-BY-EXPT.csv')
df_rf = pd.read_csv('PC-DATA-BY-EXPT-RF-SUP.csv')

# colors 
colors = creb.colors
GCAMP_color=creb.colors[0]
CREB_color=creb.colors[1]
DN_color=creb.colors[2]

# set seaborn pallette
sns.set_palette(colors)
sns.set_style("white")
sns.set_style("ticks")
sns.set_context("talk")

# %%
dfs=[df_hr,df_rf]
big_df = pd.concat(dfs)

# %% [markdown]
# # Plot

# %%
sns.catplot(x='experimentType',y="trans_frequency", hue='expt_grp',kind='bar',data=big_df)

# %%
big_df.columns
# Out:
# Index([u'Unnamed: 0', u'sensitivity', u'expt_grp', u'specificity', u'pf_width',
#        u'trans_amplitude', u'trans_duration', u'trans_frequency',
#        u'trans_auc_nr', u'trans_amplitude_nr', u'trans_duration_nr',
#        u'trans_frequency_nr', u'trans_auc_all', u'trans_amplitude_all',
#        u'trans_duration_all', u'trans_frequency_all', u'circ_var',
#        u'circ_var_p', u'spatial_information', u'n_place_fields', u'trial_id',
#        u'condition', u'day', u'session', u'experimentType', u'startTime',
#        u'mouseID', u'session_day'],
#       dtype='object')

# %%
# ACTIvity

# %%
ax = sns.catplot(x='experimentType',y="trans_auc_all", hue='expt_grp',kind='bar',data=big_df)
ax.set_xticklabels(rotation=30)

# %%
ax = sns.catplot(x='experimentType',y="trans_frequency_all", hue='expt_grp',kind='bar',data=big_df)
ax.set_xticklabels(rotation=30)

# %%
#

# %%
ax = sns.catplot(x='experimentType',y="specificity", hue='expt_grp',kind='bar',data=big_df)
ax.set_xticklabels(rotation=30)
