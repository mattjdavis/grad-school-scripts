# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#TEST-2-:-backwards-expansion" data-toc-modified-id="TEST-2-:-backwards-expansion-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>TEST 2 : backwards expansion</a></span></li><li><span><a href="#TEST-1" data-toc-modified-id="TEST-1-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>TEST 1</a></span></li></ul></div>

# %%
from lab.figures import place_cell_figures as pcf

# %%
from lab.figures import place_cell_figures as pcf
exptGrps,roi_filters = creb.load_creb_experiments(filter_type='place')
# Out:
# LOADED EXPERIMENT GROUPS: CREB,dn-CREB,Control
# Using filter...place

# %% [markdown]
# # TEST 2 : backwards expansion

# %%
# example
#func1 = lambda df: (df['condition_day_session'] == 'A_2_1') & (df['mouseID']=='mjd535')


#control 
exptGrp = exptGrps[0]
func1 = lambda df: (df['condition_day_session'] == 'B_1_1') & (df['mouseID']=='mjd535')
cols = ['condition_day_session','mouseID']
grp1 = exptGrp.filterby(filter_fn=func1,include_columns=cols,inplace=False)

# %%
grp1.data()
# Out:
# {< Experiment: mjd535, trial_id = 13212, session = 2, lap_tolerance = 0.02, experimentType = hiddenRewards, laps = 15, stopTime = 2018-06-22-14h22m36s, uniqueLocationKey = , odorant = carvone, belt = mjd4, tSeriesDirectory = /home/matt/creb/CREB9/mjd535/20180622-RF-MJD4-2-5-2, track_length = 2000, lap_reset_tag = 7F001B08305C, position_scale = 2.09, startTime = 2018-06-22-14h10m36s, trial_length = 720, sensors = [{"report_pin": 20, "action": "create", "type": "lickport", "pin": 2}, {"action": "create", "type": "rfid_reader", "pin": 22}], day = 5, condition = 2, contexts = [{"action": "create", "durations": [-1], "type": "constant", "id": "odor_context", "valves": [4]}, {"durations": [500], "interval": 2000, "frequency": 3000, "action": "create", "type": "pulsed", "id": "tone_context", "valves": [26]}, {"max_duration": 3, "pin": 5, "sensor": 2, "durations": [30], "display_color": [0, 204, 0], "locations": [1690], "operant_rate": 1, "initial_open": 0, "drop_size": 30, "timeout": 2005, 
# ...

# %% [markdown]
# # TEST 1

# %%
# example
#func1 = lambda df: (df['condition_day_session'] == 'A_2_1') & (df['mouseID']=='mjd535')


#control 
exptGrp = exptGrps[0]
func1 = lambda df: (df['condition_day_session'] == 'B_1_1') & (df['mouseID']=='mjd535')
cols = ['condition_day_session','mouseID']
grp1 = exptGrp.filterby(filter_fn=func1,include_columns=cols,inplace=False)

# %%
exptGrp = exptGrps[2]
func1 = lambda df: (df['condition_day_session'] == 'B_1_1') 
cols = ['condition_day_session','mouseID']
grp1 = exptGrp.filterby(filter_fn=func1,include_columns=cols,inplace=False)

for g in grp1:
    print g.get('laps')
# Out:
# 15
# 17
# 14
# 42

# %%
pcf.place_cell_heatmaps(grp1,roi_filter=None,pcs_only=False,show_pf=False,smooth_x=True)
# Out:
# Turned roi title off
# mjd535 2018-06-22-14h10m36s
# <ROI set: nROIs=212, timestamp=None>
# [<Figure size 432x720 with 2 Axes>,
#  <Figure size 432x720 with 2 Axes>,
#  <Figure size 432x720 with 2 Axes>,
#  <Figure size 432x720 with 2 Axes>,
#  <Figure size 432x720 with 2 Axes>,
#  <Figure size 432x720 with 2 Axes>,
#  <Figure size 432x720 with 2 Axes>,
#  <Figure size 432x720 with 2 Axes>,
#  <Figure size 432x720 with 2 Axes>,
#  <Figure size 432x720 with 2 Axes>,
#  <Figure size 432x720 with 2 Axes>,
#  <Figure size 432x720 with 2 Axes>,
#  <Figure size 432x720 with 2 Axes>,
#  <Figure size 432x720 with 2 Axes>,
#  <Figure size 432x720 with 2 Axes>,
#  <Figure size 432x720 with 2 Axes>,
#  <Figure size 432x720 with 2 Axes>,
#  <Figure size 432x720 with 2 Axes>,
#  <Figure size 432x720 with 2 Axes>,
#  <Figure size 432x720 with 2 Axes>,
#  <Figure size 432x720 with 2 Axes>,
#  <Figure size 432x720 with 2 Axes>,
#  <Figure size 432x720 with 2 Axes>,
# ...
