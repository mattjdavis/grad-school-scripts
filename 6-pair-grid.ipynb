# %%
# %matplotlib inline

# %%
df_expt = pd.read_csv('big-df-by-expt-with-stab.csv')
df_day = df_expt.query("pairing=='day'")
df_session = df_expt.query("pairing=='session'")

# %% [markdown]
# mjdplot.heatMap(df_day.query("grp=='Control'").select_dtypes("float64"),False)

# %%
mjdplot.heatMap(df_session.query("grp=='Control'").select_dtypes("float64"),False)

# %%
mjdplot.heatMap(df_session.query("grp=='CREB'").select_dtypes("float64"),False)

# %%
mjdplot.heatMap(df_session.query("grp=='dn-CREB'").select_dtypes("float64"),False)
